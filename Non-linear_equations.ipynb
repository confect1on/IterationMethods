# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
def draw_function(f, a, b):
    x = np.linspace(a, b, 100)
    y = f(x)
    fig, ax = plt.subplots()

    ax.plot(x, y, linewidth=2.0)
    ax.set(xlim=(a, b), xticks=np.arange(a, b),
       ylim=(-10, 10), yticks=np.arange(-10, 10))
    plt.axvline(0)
    plt.axhline(0)
    plt.show()

# %%
def bisection(f, a, b):
    pass

def f(x):
    return x ** 3 - 3 * x - 2 * math.e ** (-x)

def g(x):
    return x - 1 / np.arctan(x)

# %%
draw_function(g, -10, 10)
bisection(g, 1, 3)
